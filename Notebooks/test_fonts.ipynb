# %%
from matplotlib import font_manager
import matplotlib as mpl

# %%
mpl.__version__
# Out:
# '3.8.4'

# %%
# List all available font names
font_list = sorted({f.name for f in font_manager.fontManager.ttflist})
for font in font_list: print(font)
# Out:
# DejaVu Sans
# DejaVu Sans Display
# DejaVu Sans Mono
# DejaVu Serif
# DejaVu Serif Display
# East Syriac Adiabene
# East Syriac Ctesiphon
# Estrangelo Antioch
# Estrangelo Edessa
# Estrangelo Midyat
# Estrangelo Nisibin
# Estrangelo Nisibin Outline
# Estrangelo Quenneshrin
# Estrangelo Talada
# Estrangelo TurAbdin
# Goha-Tibeb Zemen
# Helvetica
# Inconsolata
# Liberation Mono
# Liberation Sans
# Liberation Sans Narrow
# Liberation Serif
# Luxi Mono
# Luxi Sans
# Luxi Serif
# STIXGeneral
# STIXNonUnicode
# STIXSizeFiveSym
# STIXSizeFourSym
# STIXSizeOneSym
# STIXSizeThreeSym
# STIXSizeTwoSym
# Serto Batnan
# Serto Jerusalem
# Serto Jerusalem Outline
# Serto Kharput
# Serto Malankara
# Serto Mardin
# Serto Urhoy
# Source Code Pro
# Ubuntu
# Ubuntu Condensed
# Ubuntu Mono
# cmb10
# cmex10
# cmmi10
# cmr10
# cmss10
# cmsy10
# cmtt10

# %%
# Rebuild the font cache
# font_manager.fontManager.addfont('path/to/font.ttf')  # Optional: add a specific font
font_manager.fontManager.findfont('DejaVu Sans')  # This will trigger cache rebuild
# Out:
# '/global/u1/f/feng045/envs/py310_home/lib/python3.12/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
